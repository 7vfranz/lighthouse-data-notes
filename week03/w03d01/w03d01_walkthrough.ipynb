# %%
# From Lecture

# %%
import seaborn as sns
import matplotlib.pyplot as plt 

# matplot lib - stateful-more object oriented and stateless -
# i.e. use: fig,ax= plt.subplots() 
# ax. to plot 
# fig is the entire figure, ax=axis, if 1 then only 1  

# for plotting use df['col'].values # to get a numpy array and it's clear,just specifing the col sometimes work, less reliable
# plt.show() if not in ipynb

# seaborn is built on top of matplotlib - doesn't show as much
# less customizable than matplotlib 
# data expected is dataframe, then pass the x and y arguments
#  
# can integrate with matplotlib
# ax = sns.scatterplot(x='', y='', data =df)
# then can do set_xlabel() other matplot lib

# ax=axes[] specificed within sns.scatterlpot - 
# plt.save_fig('name.png') to save

# sns.set_context('') - changing the size of legend e.g. for 'talk' changes the scale of everything

# %%
# import numpy
import numpy as np

# import matplotlib
import matplotlib.pyplot as plt

# set the figure size for each figure in this tutorial
plt.rcParams["figure.figsize"] = (10,6)

# %%
x = np.linspace(0,100,200)
y = np.sin(x)

# a line plot
plt.plot(x,y,'red')
plt.show()

# %%
x = 10*np.random.rand(200,1)

# 200 random values from the interval <0,15>
y = 15*np.random.rand(200,1)

# a scatter plot 
plt.scatter(x,y)
plt.show()

# %%
# 200 random values from the interval <0,15>
y = 15*np.random.rand(200,1)

# a histogram with 20 bins
plt.hist(y,bins=20)
plt.show()

# %%
# common axes
# 200 values from the interval <0,100>, equidistantly divided
x = np.linspace(0,100,200)

# sin(x) values
y1 = np.sin(x)

# sin(x)*cos(x) values
y2 =(np.sin(x))*(np.cos(x))

# a line plot of sin(x), red line
plt.plot(x,y1,'red')

# a line plot of sin(x)*cos(x), blue line
plt.plot(x,y2,'blue')
plt.show()

# %%
plt.subplot(2,1,1)
plt.plot(x,y1,'red')
plt.title('sin(x)')

# the second figure
plt.subplot(2,1,2)
plt.plot(x,y2,'blue')
plt.title('sin(x)*(cos(x))')

# automatically adjust the subplot parameters to give a specified padding
plt.tight_layout()
plt.show()

# %%
# import pandas
import pandas as pd

# import sklearn datasets
from sklearn import datasets

# %%
# load iris dataset
iris = datasets.load_iris()

# create dataframe
iris_df = pd.DataFrame(iris.data, columns=iris.feature_names)

# create target
iris_df['target'] = iris.target

# map the target values to the target names
iris_df['target_name'] =iris_df.target.map(
    {0: 'setosa', 
     1: 'versicolor',
     2: 'virginica'}
)

# %%
setosa = iris_df[iris_df.target_name == 'setosa']

# Iris versicolor
versicolor = iris_df[iris_df.target_name == 'versicolor']

# Iris virginica
virginica = iris_df[iris_df.target_name == 'virginica']

# plot setosa
plt.scatter(setosa['sepal length (cm)'], setosa['sepal width (cm)'],
            marker ='o', color = 'red', label = 'setosa')

# plot versicolor
plt.scatter(versicolor['sepal length (cm)'], versicolor['sepal width (cm)'],
            marker ='o', color = 'green', label = 'versicolor')

# plot virginica
plt.scatter(virginica['sepal length (cm)'], virginica['sepal width (cm)'],
            marker ='o', color = 'blue', label = 'virginica')

# legend location
plt.legend(loc='upper right')

# plot title
plt.title('Iris flower')

# x-axis title
plt.xlabel('sepal length (cm)')

# y-axis title
plt.ylabel('sepal width (cm)')
plt.show()

# %%
plt.scatter(setosa['sepal length (cm)'],setosa['sepal width (cm)'],
            marker ='o', color = 'red', label = 'setosa')

plt.scatter(versicolor['sepal length (cm)'],versicolor['sepal width (cm)'],
            marker ='o', color = 'green', label = 'versicolor')

plt.scatter(virginica['sepal length (cm)'],virginica['sepal width (cm)'],
            marker ='o', color = 'blue', label = 'virginica')

# new lines of code
# it can be tricky to find the right coordinates for the first time
######################
plt.annotate('setosa', xy =(5.0,3.5),
             xytext = (4.25,4.0), arrowprops={'color':'red'})
plt.annotate('versicolor', xy =(7.2,3.6),
             xytext = (6.5,4.0), arrowprops={'color':'red'}) # xy and arrow props for the arrow
plt.annotate('virginica', xy = (5.5,1.75)) # xytest for text
######################

# the same code as before
plt.legend(loc='upper right')
plt.title('Iris flower')
plt.xlabel('sepal length (cm)')
plt.ylabel('sepal width (cm)')
plt.ylim(1.5,4.7)
plt.show()

# %% [markdown]
# #### Seaborn

# %% [markdown]
# https://seaborn.pydata.org/introduction.html

# %% [markdown]
# * sns
# * can also customize within preset
# * sns.set_theme()
#     * options: https://seaborn.pydata.org/tutorial/aesthetics.html
#     * useful 'whitegrid' or 'despine'
# * .set_context("") for different preformats
# * .load_dataset("") for quick access
# * sns.relplot(data="",x,y,col,hue,style,size)
#     * all can be specified to different groups
#     * col = column for two side by side plots
#
# * some sns will already calculate mean and error bars
# * sns.lmplot() - auto does linear regression
#
# * sns.distplot - distribution plot
#     * kde=True - adds the kernal density estimation
#     * rug=True - adds a rug plot underneath
#
# * sns.catplot - categorical data
#     * kind='swarm','violin', 'bar'
#
# * sns.jointplot - composite views
#     * adds aggregate on top and right
#
# * sns.pairplot - does all pairwise relationships for each variable - see link for example
#
# * when polishing and more tweaking:
#     * assign the default plot as an object: g = sns.relplot()
#     * g.set_axis_labels, g.legend.set_title, g.figure.set_size_inches etc. can all be customized after
#
# * matplotlib more customization - but more complex
# * must know when to switch from matplot to seaborn and viceversa

# %% [markdown]
# #### Plotly

# %% [markdown]
# * will open an html
# * px.line, px.bar
# * print(fig) to see JSON of data
# * fig.show() to see the graph within Python
# * can be used to make analytical apps - exporting the graph as an app
# * allows to customize on html - see (https://plotly.com/python/getting-started/)
# * https://plotly.com/python/figure-structure/
# * useful for plotting choropleths - or map visualiations
# * map tracers useful..

# %%
import plotly.express as px
fig = px.bar(x=["a", "b", "c"], y=[1, 3, 2])
# fig.write_html('first_figure.html', auto_open=True)
fig.show()

# %%
import plotly.graph_objs as go

# %%
random_x = np.random.randint(1,101,100)
random_y = np.random.randint(1,101,100)

# %%
# creates the data
data = [go.Scatter(
    x = random_x,
    y = random_y,
    mode = 'markers',
)]

# %%
layout = go.Layout(
    title = 'Random Data Scatterplot', # Graph title
    xaxis = dict(title = 'Some random x-values'), # x-axis label
    yaxis = dict(title = 'Some random y-values'), # y-axis label
    hovermode ='closest' # handles multiple points landing on the same vertical
)

# %%
fig = go.Figure(data=data, layout=layout)
fig.show()

# %%
x_values = np.linspace(0, 1, 100)
y_values = np.random.randn(100)

# %%
trace0 = go.Scatter(
    x = x_values,
    y = y_values+5,
    mode = 'markers',
    name = 'markers'
)

# %%
trace1 = go.Scatter(
    x = x_values,
    y = y_values,
    mode = 'lines+markers',
    name = 'lines+markers'
)

# %%
trace2 = go.Scatter(
    x = x_values,
    y = y_values-5,
    mode = 'lines',
    name = 'lines'
)

# %%
data = [trace0, trace1, trace2]

# %%
layout = go.Layout(
    title = 'Line chart showing three different modes'
)

# %%
fig = go.Figure(data=data,layout=layout)
fig.show()

# %%
# Plotly from a dataframe

# %%
df_olympic = pd.read_csv('https://raw.githubusercontent.com/Pierian-Data/Plotly-Dashboards-with-Dash/master/Data/2018WinterOlympics.csv',sep =',')

# %%
df_olympic.head()
# Out:
#    Rank            NOC  Gold  Silver  Bronze  Total
# 0     1         Norway    14      14      11     39
# 1     2        Germany    14      10       7     31
# 2     3         Canada    11       8      10     29
# 3     4  United States     9       8       6     23
# 4     5    Netherlands     8       6       6     20

# %%
data = [go.Bar(
    x=df_olympic['NOC'],  # NOC stands for the National Olympic Committee
    y=df_olympic['Total']
)]

# %%
layout = go.Layout(
    title='2018 Winter Olympic Medals by Country'
)

# %%
fig = go.Figure(data=data, layout=layout)
fig.show()

# %%
# creating separate bars for each group 
trace1 = go.Bar(
    x=df_olympic['NOC'],  # NOC stands for the National Olympic Committee
    y=df_olympic['Gold'],
    name = 'Gold',
    marker=dict(color='#FFD700') # set the marker color to gold
)

# trace2 - silver medals
trace2 = go.Bar(
    x=df_olympic['NOC'],
    y=df_olympic['Silver'],
    name='Silver',
    marker=dict(color='#9EA0A1') # set the marker color to silver
)

# trace3 - bronze medals
trace3 = go.Bar(
    x=df_olympic['NOC'],
    y=df_olympic['Bronze'],
    name='Bronze',
    marker=dict(color='#CD7F32') # set the marker color to bronze
)

# %%
# create the data
data = [trace1, trace2, trace3]

# create the layout
layout = go.Layout(
    title='2018 Winter Olympic Medals by Country'
)

# %%
# create the figure
fig = go.Figure(data=data, layout=layout)
fig.show()

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Pierian-Data/Plotly-Dashboards-with-Dash/master/Data/arrhythmia.csv',sep=',')

# %%
df.head()
# Out:
#    Age  Sex  Height
# 0   68    1     146
# 1   58    1     148
# 2   36    1     149
# 3   34    1     150
# 4   40    1     150

# %%
data = [
    # men
    go.Histogram(
    x=df[df['Sex']==0]['Height'],
    opacity=0.75,
    name='Male'
),  
    # women
    go.Histogram(
    x=df[df['Sex']==1]['Height'],
    opacity=0.75,
    name='Female'
)]

# create the layout
layout = go.Layout(
    barmode='overlay',
    title="Height comparison by gender"
)

# create the figure 
fig = go.Figure(data=data, layout=layout)
fig.show()
