# %%
# import numpy
import numpy as np

# import matplotlib
import matplotlib.pyplot as plt

# %%
# 200 values from the interval <0,100>, equidistantly divided
x = np.linspace(0,100,200)
y = np.sin(x)

# create the figure and axes, set the figure size
fig, ax = plt.subplots(figsize = (10,6))

# plot the line
ax.plot(x,y,'red') # note use of ax, default is 1,1 for subplots
plt.show()

# %%
# 200 random values from the interval <0,10>
x = 10*np.random.rand(200,1)

# 200 random values from the interval <0,15>
y = 15*np.random.rand(200,1)

# create the figure and axes, set the figure size
fig, ax = plt.subplots(figsize = (10,6))

# scatter plot
ax.scatter(x,y)
plt.show()

# %%
# 200 random values from the interval <0,15>
y = 15*np.random.rand(200,1)

# create the figure and axes, set the figure size
fig, ax = plt.subplots(figsize = (10,6))

# histogram
ax.hist(y,bins=20)
plt.show()

# %%
# plotting graphs on a common axis 

x = np.linspace(0,100,200)

# sin(x) values
y1 = np.sin(x)

# sin(x)*cos(x) values
y2 =(np.sin(x))*(np.cos(x))

# create the figure and axes, set the figure size
fig, ax = plt.subplots(figsize = (10,6))

# sin(x) plot 
ax.plot(x,y1,'red')

# sin(x)*cos(x) plpt
ax.plot(x,y2,'blue')
plt.show()

# %%
# HAVING ACTUAL SUBPLOTS
fig, axes = plt.subplots(nrows=2, ncols=1 ,figsize = (10,6))

# the first plot 
axes[0].plot(x,y1,'red')

# the first plot title
axes[0].set_title('sin(x)')

# the second plot
axes[1].plot(x,y2,'blue')

# the second plot title
axes[1].set_title('sin(x)*(cos(x))')

# automatically adjust the subplot parameters to give specified padding
fig.tight_layout()
plt.show()

# %%
from sklearn import datasets
import pandas as pd

# %%
# load the iris dataset
iris = datasets.load_iris()

# create a dataframe
iris_df = pd.DataFrame(iris.data, columns=iris.feature_names)

# create a target
iris_df['target'] = iris.target

# map target values to target names
iris_df['target_name'] =iris_df.target.map(
    {0: 'setosa', 
     1: 'versicolor',
     2: 'virginica'}
)

# %%
# Iris setosa
setosa = iris_df[iris_df.target_name == 'setosa']

# Iris versicolor
versicolor = iris_df[iris_df.target_name == 'versicolor']

# Iris virginica
virginica = iris_df[iris_df.target_name == 'virginica']

# create the figure and axes, set the figure size
fig, ax = plt.subplots(figsize=(10,6))

# scatter the plot of setosa
ax.scatter(setosa['sepal length (cm)'],setosa['sepal width (cm)'],
            marker ='o', color = 'red', label = 'setosa')


# scatter the plot of versicolor
ax.scatter(versicolor['sepal length (cm)'],versicolor['sepal width (cm)'],
            marker ='o', color = 'green', label = 'versicolor')


# scatter the plot of virginica
ax.scatter(virginica['sepal length (cm)'],virginica['sepal width (cm)'],
            marker ='o', color = 'blue', label = 'virginica')

# set the legend
ax.legend(loc='upper right')

# set the title
ax.set_title('Iris flower')

# set the x-label
ax.set_xlabel('sepal length (cm)')

# set the y-label
ax.set_ylabel('sepal width (cm)')
plt.show()

# %%
# create the figure and axes, set the figure size
fig, ax = plt.subplots(figsize=(10,6))

# scatter the plot of setosa
ax.scatter(setosa['sepal length (cm)'],setosa['sepal width (cm)'],
            marker ='o', color = 'red', label = 'setosa')


# scatter the plot of versicolor
ax.scatter(versicolor['sepal length (cm)'],versicolor['sepal width (cm)'],
            marker ='o', color = 'green', label = 'versicolor')


# scatter the plot of virginica
ax.scatter(virginica['sepal length (cm)'],virginica['sepal width (cm)'],
            marker ='o', color = 'blue', label = 'virginica')

# new lines of code
######################
ax.annotate('setosa', xy =(5.0,3.5),
             xytext = (4.25,4.0), arrowprops={'color':'red'})
ax.annotate('versicolor', xy =(7.2,3.6),
             xytext = (6.5,4.0), arrowprops={'color':'red'})
ax.annotate('virginica', xy =(5.05,1.95),
             xytext = (5.5,1.75), arrowprops={'color':'red'})
######################


# set the legend
ax.legend(loc='upper right')

# set the title
ax.set_title('Iris flower')

# set the x-label
ax.set_xlabel('sepal length (cm)')

# set the y-label
ax.set_ylabel('sepal width (cm)')

# set the x-range 
ax.set_xlim(4,8)

# set the y-range
ax.set_ylim(1.5,4.7)
plt.show()

# %% [markdown]
# #### 3D Plotting in Matplot

# %%
from mpl_toolkits import mplot3d

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

# %%
ax = plt.axes(projection='3d')

# Data for a three-dimensional line
zline = np.linspace(0, 15, 1000)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline, yline, zline, 'gray')

# Data for three-dimensional scattered points
zdata = 15 * np.random.random(100)
xdata = np.sin(zdata) + 0.1 * np.random.randn(100)
ydata = np.cos(zdata) + 0.1 * np.random.randn(100)
ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='Greens');

# %% [markdown]
# #### Contour Plots

# %%
def f(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 50, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');

# %%
# changes the view of the figure, 60 degrees above x-y, 35 azimuth, rotated ccw around the z-axis
ax.view_init(60, 35)
fig

# %% [markdown]
# #### Wireframe and Surface Plots

# %%
# alternative to countour plots
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_wireframe(X, Y, Z, color='black')
ax.set_title('wireframe');

# %%
# surface plots
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
ax.set_title('surface');

# %%
# does not need to be recrilinear? - can be missing ? not the same lengths along each axis
r = np.linspace(0, 6, 20)
theta = np.linspace(-0.9 * np.pi, 0.8 * np.pi, 40)
r, theta = np.meshgrid(r, theta)

X = r * np.sin(theta)
Y = r * np.cos(theta)
Z = f(X, Y)

ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none');

# %% [markdown]
# #### Surface Triangulations

# %%
# random draws instead of a even draw from a cartesian or polar grid
theta = 2 * np.pi * np.random.random(1000)
r = 6 * np.random.random(1000)
x = np.ravel(r * np.sin(theta))
y = np.ravel(r * np.cos(theta))
z = f(x, y)

# %%
ax = plt.axes(projection='3d')
ax.scatter(x, y, z, c=z, cmap='viridis', linewidth=0.5);

# %%
# creates a surface by finding a set of triangles formed between adjacent points 
ax = plt.axes(projection='3d')
ax.plot_trisurf(x, y, z,
                cmap='viridis', edgecolor='none');

# %% [markdown]
# Mobius Strip example - paper glued into a loop with a half-twist

# %% [markdown]
# * has two intrinsic dimensions, around the loop and width of strip

# %%
theta = np.linspace(0, 2 * np.pi, 30)
w = np.linspace(-0.25, 0.25, 8)
w, theta = np.meshgrid(w, theta)

# %%
#half twist during the full loop
phi = 0.5 * theta

# %%
# radius in x-y plane
r = 1 + w * np.cos(phi)

x = np.ravel(r * np.cos(theta))
y = np.ravel(r * np.sin(theta))
z = np.ravel(w * np.sin(phi))

# %%
# triangulate in the underlying parametrization
from matplotlib.tri import Triangulation
tri = Triangulation(np.ravel(w), np.ravel(theta))

ax = plt.axes(projection='3d')
ax.plot_trisurf(x, y, z, triangles=tri.triangles,
                cmap='viridis', linewidths=0.2);

ax.set_xlim(-1, 1); ax.set_ylim(-1, 1); ax.set_zlim(-1, 1);

# %% [markdown]
# ## Walkthrough from Compass

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal

# %%
ax = plt.axes(projection='3d')

# %%
x = np.linspace(-10,10,500)
y = np.linspace(-10,10,500)

# a Cartesian product
X,Y = np.meshgrid(x,y)

# %%
# the parameters of the distribution
# x
mu_x = 0
variance_x = 10

# y
mu_y = 0
variance_y = 10

# a means list
means = [mu_x, mu_y]

# a covariance
cov = [[variance_x, 0], [0, variance_y]]

# a multivariate normal distribution
mn = multivariate_normal(means, cov)

# %%
# a position matrix
position = np.array([X,Y]).T

# z-coordinates from a probability-density function
Z = mn.pdf(position)

# %%
# WIRE PLOT
#  create the figure and axes
fig,ax = plt.subplots(figsize=(12.8,9.6))

# set a 3D projection
ax = plt.axes(projection='3d')

# a wireframe
ax.plot_wireframe(X, Y, Z, color='r')
plt.show()

# %%
# SURFACE PLOT
#  create the figure and axes
fig,ax = plt.subplots(figsize=(12.8,9.6))

# set a 3D projection
ax = plt.axes(projection='3d')

# the surface
ax.plot_surface(X, Y, Z, cmap='jet')
plt.show()

# %%
# CONTOUR PLOT
#  create the figure and axes
fig,ax = plt.subplots(figsize=(12.8,9.6))

# set a 3D projection
ax = plt.axes(projection='3d')

# the surface
ax.contour(X, Y, Z, 40, cmap='viridis') #40 is number of contour lines to draw
plt.show()

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
world.head()
# Out:
#      pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     920938        Oceania                      Fiji    FJI      8374.0
# 1   53950935         Africa                  Tanzania    TZA    150600.0
# 2     603253         Africa                 W. Sahara    ESH       906.5
# 3   35623680  North America                    Canada    CAN   1674000.0
# 4  326625791  North America  United States of America    USA  18560000.0
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...

# %%
# works the same way as pandas with additional geometry dtype
# geometry type has classes - geometric (Shapely) objects, points, lines, polygons
world.dtypes
# Out:
# pop_est          int64
# continent       object
# name            object
# iso_a3          object
# gdp_md_est     float64
# geometry      geometry
# dtype: object

# %%
world.geometry.name
# Out:
# 'geometry'

# %%
# changing column name to borders and setting it as a geometry type 
world = world.rename(columns={'geometry': 'borders'}).set_geometry('borders')

# %%
world.geometry.name
# Out:
# 'borders'

# %%
# for plotting same as you would with any matplotlib
world.plot()
# Out:
# <AxesSubplot:>

# %%
# can easily make choropleth maps - where color  is based on value of the variable
# note kwds = keywords for each legend argument - means input a dictionary
fig, ax = plt.subplots(figsize=(16,9))
world.plot(column='pop_est', ax=ax, legend=True, legend_kwds={'label': "Population by Country",
                        'orientation': "horizontal"})
# Out:
# <AxesSubplot:>

# %%
# filter the data-frame to exclude antartical
world = world[(world.pop_est>0) & (world.name!="Antarctica")]

# create the figure and axes
fig, ax = plt.subplots(figsize=(15,12))

# create the map
world.plot(column='pop_est', ax=ax, legend=True,
           legend_kwds={'label': "Population by Country",
                        'orientation': "horizontal"})
plt.show()

# %% [markdown]
# #### For plotting cities

# %%
cities = gpd.read_file(gpd.datasets.get_path('naturalearth_cities'))
# only contains points of cities - which needs to be superimposed onto the map - no polygons

# %%
cities.head()
# Out:
#            name                   geometry
# 0  Vatican City  POINT (12.45339 41.90328)
# 1    San Marino  POINT (12.44177 43.93610)
# 2         Vaduz   POINT (9.51667 47.13372)
# 3    Luxembourg   POINT (6.13000 49.61166)
# 4       Palikir  POINT (158.14997 6.91664)

# %%
fig, ax = plt.subplots(figsize=(15,12))

# a layer of countries
world.plot(column='pop_est', ax=ax, legend=True,
           legend_kwds={'label': "Population by Country",
                        'orientation': "horizontal"})

# a layer of cities
cities.plot(ax=ax ,marker='*', color='white', markersize=5)
plt.show()

# %% [markdown]
# #### with Plotly

# %%
world.head()
# Out:
#      pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     920938        Oceania                      Fiji    FJI      8374.0
# 1   53950935         Africa                  Tanzania    TZA    150600.0
# 2     603253         Africa                 W. Sahara    ESH       906.5
# 3   35623680  North America                    Canada    CAN   1674000.0
# 4  326625791  North America  United States of America    USA  18560000.0
#
#                                              borders
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...

# %%
import plotly.graph_objects as go
import pandas as pd

# %%
worlddata1 = go.Choropleth(
    locations=world['iso_a3'],
    z = world['pop_est'],
    colorscale='Reds',
    colorbar_title = "Population Estimate"
)

# %%
worldfig = go.Figure(data=worlddata1)
worldfig.show()

# %%
sizeref = (max(world['pop_est']) / 1000000000)

# %%
worlddata2 = go.Scattergeo(
    locations=world['iso_a3'],
    marker=dict(size=world['pop_est']/1000000,
    sizemode='area', sizeref=1.3)
    )

# %%
worldfig2 = go.Figure(data=worlddata2)
worldfig2.show()

# %%
import plotly.express as px

# %%
world.head()
# Out:
#      pop_est      continent                      name iso_a3  gdp_md_est  \
# 0     920938        Oceania                      Fiji    FJI      8374.0
# 1   53950935         Africa                  Tanzania    TZA    150600.0
# 2     603253         Africa                 W. Sahara    ESH       906.5
# 3   35623680  North America                    Canada    CAN   1674000.0
# 4  326625791  North America  United States of America    USA  18560000.0
#
#                                              borders
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...

# %%
worldfig3 = px.scatter_geo(world, locations='iso_a3', color='continent', size='pop_est')
worldfig3.show()

# %% [markdown]
# #### ipywidgets

# %%
import ipywidgets as widgets
import plotly.graph_objects as go
import pandas as pd

# %%
# renderer different for vscode # can be set as renderer='notebook' in fig.show()
# import plotly.io as pio
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniforge/base/envs/lhl_env38/lib/python3.8/_collections_abc.py:660, in Mapping.get(self, key, default)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/lhl_env38/lib/python3.8/_collections_abc.py?line=658'>659</a> try:
# --> <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/lhl_env38/lib/python3.8/_collections_abc.py?line=659'>660</a>     return self[key]
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/lhl_env38/lib/python3.8/_collections_abc.py?line=660'>661</a> except KeyError:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/lhl_env38/lib/python3.8/os.py:675, in _Environ.__getitem__(self, key)
#     <a href='file:///opt/homebrew/Caskroom/miniforge/base/envs/lhl_env38/lib/python3.8/os.py?line=672'>673</a> except KeyError:
# ...

# %%
from ipywidgets import interact, interact_manual

# %%
slider = widgets.IntSlider(
    min=0,
    max=10,
    step=1,
    description='Slider:',
    value=3
)

slider
# Out:
# IntSlider(value=3, description='Slider:', max=10)

# %%
print(slider.value)
# Out:
# 3

# %%
# different type of widgets available - interact probably the best
print(dir(widgets))
# Out:
# ['Accordion', 'AppLayout', 'Audio', 'BoundedFloatText', 'BoundedIntText', 'Box', 'Button', 'ButtonStyle', 'CallbackDispatcher', 'Checkbox', 'Color', 'ColorPicker', 'Combobox', 'Controller', 'CoreWidget', 'DOMWidget', 'DatePicker', 'Datetime', 'Dropdown', 'FileUpload', 'FloatLogSlider', 'FloatProgress', 'FloatRangeSlider', 'FloatSlider', 'FloatText', 'GridBox', 'GridspecLayout', 'HBox', 'HTML', 'HTMLMath', 'Image', 'IntProgress', 'IntRangeSlider', 'IntSlider', 'IntText', 'Label', 'Layout', 'NumberFormat', 'Output', 'Password', 'Play', 'RadioButtons', 'Select', 'SelectMultiple', 'SelectionRangeSlider', 'SelectionSlider', 'SliderStyle', 'Style', 'Tab', 'Text', 'Textarea', 'ToggleButton', 'ToggleButtons', 'ToggleButtonsStyle', 'TwoByTwoLayout', 'VBox', 'Valid', 'ValueWidget', 'Video', 'Widget', '__builtins__', '__cached__', '__doc__', '__file__', '__jupyter_widgets_base_version__', '__jupyter_widgets_controls_version__', '__loader__', '__name__', '__package__', '__path__', '__protocol_ve
# ...

# %%
# the data url
url = "https://data.london.gov.uk/download/number-international-visitors-london/b1e0f953-4c8a-4b45-95f5-e0d143d5641e/international-visitors-london-raw.csv"

# create the data-frame
df_london = pd.read_csv(url, encoding= 'unicode_escape')
df_london.columns = ["year","quarter","market","dur_stay","mode","purpose","area","visits","spend","nights","sample"]

# sample 200 rows
df = df_london.sample(200)

# %%
df.head()
# Out:
#        year         quarter       market     dur_stay mode   purpose     area  \
# 33137  2011  July-September  New Zealand  15+  nights  Air  Business   LONDON
# 34888  2012   January-March       Israel  4-7  nights  Air       VFR   LONDON
# 5580   2003  July-September        Japan  4-7  nights  Air       VFR   LONDON
# 25510  2009  July-September       Sweden  15+  nights  Air       VFR   LONDON
# 18643  2007      April-June        India  15+  nights  Air   Holiday   LONDON
#
#          visits     spend      nights  sample
# 33137  0.877214  3.128810   14.066035       2
# 34888  5.635868  2.634074   26.892808       6
# 5580   1.840051  0.760920    7.784621       5
# 25510  5.921459  0.826217   70.271409       9
# 18643  5.641174  4.620586  111.435881      12

# %%
def filter_df(column, threshold):
    return df[df[column] <= threshold]

# %%
filter_widget = widgets.interact(filter_df,
                                 column=['spend','visits'], 
                                 threshold=(1, 30, 1))
# Out:
# interactive(children=(Dropdown(description='column', options=('spend', 'visits'), value='spend'), IntSlider(va…

# %%
# to store for later use
filter_widget.widget
# Out:
# interactive(children=(Dropdown(description='column', index=1, options=('spend', 'visits'), value='visits'), In…

# %%
# GRAPHS WORK IN JUPYTER LAB BUT NOT IN VSCODE

# %%
# changing x and y data with widgets - automatically once x and y are chosen
@interact
def scatter_plot(x=list(df.select_dtypes('number').columns), 
                 y=list(df.select_dtypes('number').columns)[1:]):

    # trace
    trace = [go.Scatter(x=df[x], y=df[y], mode='markers')]

    # layout
    layout = go.Layout(
                title = 'Scatter plot', # Graph title
                xaxis = dict(title = x.title()), # x-axis label
                yaxis = dict(title = y.title()), # y-axis label
                hovermode ='closest' # handles multiple points landing on the same vertical
    )

    # fig
    fig = go.Figure(trace, layout)
    fig.show()
# Out:
# interactive(children=(Dropdown(description='x', options=('visits', 'spend', 'nights', 'sample'), value='visits…

# %%
# when to run interaction
@interact_manual
def scatter_plot(x=list(df.select_dtypes('number').columns), 
                 y=list(df.select_dtypes('number').columns)[1:]):

    # trace
    trace = [go.Scatter(x=df[x], y=df[y], mode='markers')]

    # layout
    layout = go.Layout(
                title = 'Scatter plot', # Graph title
                xaxis = dict(title = x.title()), # x-axis label
                yaxis = dict(title = y.title()), # y-axis label
                hovermode ='closest' # handles multiple points landing on the same vertical
    )

    # fig
    fig = go.Figure(trace, layout)
    fig.show()
# Out:
# interactive(children=(Dropdown(description='x', options=('visits', 'spend', 'nights', 'sample'), value='visits…

# %%
@interact_manual
def scatter_plot2(x=list(df.select_dtypes('number').columns), 
                 y=list(df.select_dtypes('number').columns)[1:]):

                 plt.scatter(df[x], df[y])
# Out:
# interactive(children=(Dropdown(description='x', options=('visits', 'spend', 'nights', 'sample'), value='visits…
