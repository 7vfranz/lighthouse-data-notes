# %% [markdown]
# ## Lighthouse Labs
# ### W09D2 Time Series II
#
# Instructor: Samuel Boylan
#
# Jan 4, 2021
#
# Notebook modified from Andrew & Socorro.

# %% [markdown]
# **What will we learn today?**
#
# * Facebook Prophet
#
# * Time Series as a Supervised Learning problem
#
# * Deep Learning for Stock Prediction
#
# * Time Series Final Project Brainstorm - exercise

# %% [markdown]
# ## Facebook Prophet
#
# * FB Prophet is a procedure for forecasting time series data using a powerful toolkit created by Facebook. It allows us to decompose and model trends from time series data.
#
# * It works best with time series that have strong seasonal effects and several seasons of historical data. Prophet is robust to missing data and shifts in the trend, and typically handles outliers well.

# %% [markdown]
# ### Why use Facebook Prophet?
#
# * It is accurate and fast
#     * It is used in many applications across Facebook and it produces reliable forecasts for planning and goal setting.
#     * Forescasts in a few seconds.
# * Fully automatic
#     * No manual effort. Robust to outliers, missing data, changes in time series.
# * Tunable forecasts
#     * Users can tweak and adjust forecasts. Add your domain knowledge!
# * R or Python
#
# *   Allows us to solve various Business Analytics Questions

# %% [markdown]
# ### Predicting and Decomposing Online Sales for a Company using FB Prophet!

# %%
# Load packages
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import requests, json, os, warnings, re

# ignore warnings
import warnings
warnings.simplefilter("ignore", UserWarning)

# %%
# Model Initialize

# !pip install prophet # if you havn't done so
import fbprophet
from fbprophet import Prophet

# %%
df = pd.read_csv("https://raw.githubusercontent.com/nicknochnack/TimeSeriesForecastingProphet/main/dataset.csv")

# %%
# Preprocess the data

# %%
#Instatiate model

# %%
#Forecast into the future

# %%
#Plot

# %%
# Decompose your data

# %% [markdown]
# - The black datapoints are the real observation
# - The line is the predicted y-hat

# %% [markdown]
# ## Time Series Forecasting as Supervised Learning

# %% [markdown]
# Review:
# * What is Supervised Learning?
#
# * How is data given in SL?

# %% [markdown]
# Supervised learning is where you have input variables (X) and an output variable (y) and you use an algorithm to learn the mapping function from the input to the output.
#
# $Y = f(X)$

# %% [markdown]
# We can Shift our time series data to create a Y label
#
# Lets see this in an example for predicting the Future Price of Any Stock with an LSTM!

# %%
import math
import pandas_datareader as web
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense,LSTM
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
#Download data from here! https://ca.finance.yahoo.com/

# %%
df = pd.read_csv("BTC-USD.csv")

# %%
df
# Out:
#            Date          Open          High           Low         Close  \
# 0    2021-06-28  34679.121094  35219.890625  33902.074219  34434.335938
# 1    2021-06-29  34475.558594  36542.109375  34252.484375  35867.777344
# 2    2021-06-30  35908.386719  36074.757813  34086.152344  35040.835938
# 3    2021-07-01  35035.984375  35035.984375  32883.781250  33572.117188
# 4    2021-07-02  33549.601563  33939.589844  32770.679688  33897.046875
# ..          ...           ...           ...           ...           ...
# 361  2022-06-24  21084.648438  21472.917969  20777.511719  21231.656250
# 362  2022-06-25  21233.609375  21520.914063  20964.585938  21502.337891
# 363  2022-06-26  21496.494141  21783.724609  21016.269531  21027.294922
# 364  2022-06-27  21028.238281  21478.089844  20620.199219  20735.478516
# 365  2022-06-28  20746.535156  21164.423828  20577.003906  20668.361328
#
#         Adj Close       Volume
# 0    34434.335938  33892523752
# 1    35867.777344  37901460044
# 2    35040.835938  34059036099
# 3    33572.117188  37838957079
# 4    33897.046875  38728974942
# ..            ...          ...
# 361  21231.656250  24957784918
# 362  21502.337891  18372538715
# 363  21027.294922  18027170497
# 364  20735.478516  20965695707
# 365  20668.361328  20050356224
#
# [366 rows x 7 columns]

# %%
df.shape
# Out:
# (366, 7)

# %%
plt.figure(figsize=(16,8))
plt.title('Close Price History')
plt.plot(df['Close'])
plt.xlabel('Date',fontsize=18)
plt.ylabel('Close Price USD($)',fontsize=18)
plt.show()

# %%
data=df.filter(['Close'])
dataset=data.values
training_data_len= math.ceil(len(dataset) * .8)

#scale the data
scaler=MinMaxScaler(feature_range=(0,1))
scaled_data=scaler.fit_transform(dataset)

scaled_data
# Out:
# array([[0.31754793],
#        [0.34707348],
#        [0.33004042],
#        [0.29978823],
#        [0.30648103],
#        [0.32237213],
#        [0.33512691],
#        [0.3033699 ],
#        [0.3134461 ],
#        [0.30562172],
#        [0.28547808],
#        [0.30444113],
#        [0.29872544],
#        [0.31354892],
#        [0.29121405],
#        [0.28186637],
#        [0.28434473],
#        [0.26288985],
#        [0.25549134],
#        [0.25778858],
#        [0.26322106],
#        [0.24305638],
#        [0.22224276],
#        [0.26968631],
#        [0.27385553],
#        [0.29998254],
#        [0.31462531],
#        [0.33641234],
#        [0.37734706],
#        [0.41997201],
#        [0.43210331],
#        [0.4323611 ],
#        [0.47823468],
#        [0.46568346],
#        [0.43167052],
#        [0.41574956],
#        [0.39414333],
#        [0.4269868 ],
#        [0.45009843],
#        [0.49020096],
#        [0.5260265 ],
#        [0.51041999],
#        [0.56330007],
#        [0.54722625],
#        [0.5474035 ],
#        [0.52340006],
#        [0.59271185],
#        [0.57836815],
#        [0.57733948],
#        [0.555866  ],
#        [0.52890108],
#        [0.5310809 ],
#        [0.57055407],
#        [0.62455287],
#        [0.61562   ],
#        [0.62419193],
#        [0.62881602],
#        [0.59091567],
#        [0.61675899],
#        [0.57518115],
#        [0.61877506],
#        [0.61555636],
#        [0.61406158],
#        [0.57750385],
#        [0.57980468],
#        [0.61441576],
#        [0.62431696],
#        [0.63868697],
#        [0.63702371],
#        [0.67428047],
#        [0.69240899],
#        [0.572481  ],
#        [0.55765607],
#        [0.56383601],
#        [0.53278479],
#        [0.53932551],
#        [0.55707684],
#        [0.53441538],
#        [0.57827643],
#        [0.60060132],
#        [0.59250668],
#        [0.58188158],
#        [0.60270261],
#        [0.5817312 ],
#        [0.49076329],
#        [0.44647573],
#        [0.50581415],
#        [0.53301523],
#        [0.49067986],
#        [0.48814313],
#        [0.49827605],
#        [0.47823846],
#        [0.4534968 ],
#        [0.46440986],
#        [0.51027122],
#        [0.59937769],
#        [0.5910263 ],
#        [0.60108754],
#        [0.61989217],
#        [0.66936591],
#        [0.74859766],
#        [0.71655871],
#        [0.71989272],
#        [0.74049811],
#        [0.73644769],
#        [0.79233351],
#        [0.76259603],
#        [0.79060966],
#        [0.78897062],
#        [0.87697262],
#        [0.86251781],
#        [0.87614188],
#        [0.88587347],
#        [0.93192809],
#        [0.96757943],
#        [0.88966537],
#        [0.85840004],
#        [0.87284625],
#        [0.86331404],
#        [0.90675428],
#        [0.85163427],
#        [0.81288169],
#        [0.85695555],
#        [0.89003187],
#        [0.88304652],
#        [0.87130843],
#        [0.86482941],
#        [0.91059735],
#        [0.90531703],
#        [0.87405355],
#        [0.86732728],
#        [0.87560352],
#        [0.91266919],
#        [1.        ],
#        [0.98774439],
#        [0.94703109],
#        [0.94609864],
#        [0.92974369],
#        [0.93620283],
#        [0.95674514],
#        [0.91742483],
#        [0.84746228],
#        [0.85172117],
#        [0.78115614],
#        [0.80540868],
#        [0.83790392],
#        [0.81799177],
#        [0.767709  ],
#        [0.79406959],
#        [0.76752643],
#        [0.78800574],
#        [0.71169316],
#        [0.73734369],
#        [0.78746562],
#        [0.79896137],
#        [0.78245974],
#        [0.78708191],
#        [0.77159222],
#        [0.71227979],
#        [0.62170066],
#        [0.62516404],
#        [0.65016502],
#        [0.65258445],
#        [0.64856195],
#        [0.59021543],
#        [0.58138281],
#        [0.62503346],
#        [0.6401898 ],
#        [0.57096401],
#        [0.56839244],
#        [0.61543937],
#        [0.59007752],
#        [0.55993734],
#        [0.57325647],
#        [0.57033651],
#        [0.5739053 ],
#        [0.61626102],
#        [0.60991485],
#        [0.65432398],
#        [0.65509961],
#        [0.64701841],
#        [0.65483844],
#        [0.65135543],
#        [0.58850035],
#        [0.56493365],
#        [0.58004026],
#        [0.5620857 ],
#        [0.59051804],
#        [0.58348201],
#        [0.56520978],
#        [0.5536639 ],
#        [0.50570079],
#        [0.49729541],
#        [0.46427678],
#        [0.46790278],
#        [0.47156216],
#        [0.46970137],
#        [0.48853987],
#        [0.51352991],
#        [0.48556793],
#        [0.4960342 ],
#        [0.49763463],
#        [0.49632627],
#        [0.47854373],
#        [0.48112013],
#        [0.46811672],
#        [0.44620265],
#        [0.35921661],
#        [0.32982237],
#        [0.35549849],
#        [0.36327459],
#        [0.36944721],
#        [0.36734867],
#        [0.37324193],
#        [0.38655004],
#        [0.39383847],
#        [0.38929508],
#        [0.40094354],
#        [0.40630199],
#        [0.36942621],
#        [0.37357906],
#        [0.46310215],
#        [0.46187225],
#        [0.48187814],
#        [0.51128855],
#        [0.517018  ],
#        [0.52155673],
#        [0.50562065],
#        [0.48178553],
#        [0.47841845],
#        [0.47745133],
#        [0.48547211],
#        [0.52642614],
#        [0.51379269],
#        [0.44326942],
#        [0.43282567],
#        [0.43470376],
#        [0.39987769],
#        [0.37194524],
#        [0.39688379],
#        [0.37650328],
#        [0.39784327],
#        [0.41600237],
#        [0.41375577],
#        [0.38501454],
#        [0.49796081],
#        [0.52188299],
#        [0.51301529],
#        [0.48268877],
#        [0.41442431],
#        [0.4198411 ],
#        [0.39964299],
#        [0.39227015],
#        [0.40617833],
#        [0.47303128],
#        [0.42060064],
#        [0.40736688],
#        [0.40961283],
#        [0.38789572],
#        [0.42532354],
#        [0.41856815],
#        [0.45574991],
#        [0.45178382],
#        [0.46928725],
#        [0.47730996],
#        [0.4578899 ],
#        [0.45439184],
#        [0.48077359],
#        [0.4917758 ],
#        [0.51377362],
#        [0.52176134],
#        [0.52489419],
#        [0.57267386],
#        [0.57900789],
#        [0.58596427],
#        [0.57766204],
#        [0.54627143],
#        [0.56157486],
#        [0.5530743 ],
#        [0.56511605],
#        [0.56859931],
#        [0.54662811],
#        [0.49823896],
#        [0.50435872],
#        [0.47930817],
#        [0.48949316],
#        [0.47766052],
#        [0.42233993],
#        [0.43480732],
#        [0.45621956],
#        [0.4308594 ],
#        [0.44358771],
#        [0.44093102],
#        [0.42635752],
#        [0.44920573],
#        [0.46314078],
#        [0.46049663],
#        [0.44305008],
#        [0.42683883],
#        [0.42161547],
#        [0.4212563 ],
#        [0.44162772],
#        [0.39341172],
#        [0.41655649],
#        [0.42752902],
#        [0.40355325],
#        [0.38511938],
#        [0.40065453],
#        [0.40189522],
#        [0.38585221],
#        [0.42597478],
#        [0.36164351],
#        [0.35063985],
#        [0.33953835],
#        [0.30982236],
#        [0.23232749],
#        [0.24728043],
#        [0.20430235],
#        [0.20659686],
#        [0.21144456],
#        [0.22829679],
#        [0.25309324],
#        [0.22338738],
#        [0.23498262],
#        [0.19985153],
#        [0.2326855 ],
#        [0.20974806],
#        [0.21451614],
#        [0.23287888],
#        [0.2076506 ],
#        [0.21911682],
#        [0.21719661],
#        [0.21111749],
#        [0.19794218],
#        [0.20180066],
#        [0.21479896],
#        [0.26177057],
#        [0.26312837],
#        [0.22207247],
#        [0.23584012],
#        [0.22012209],
#        [0.22276937],
#        [0.22428841],
#        [0.25444359],
#        [0.25001111],
#        [0.23062617],
#        [0.22851785],
#        [0.20733946],
#        [0.19244747],
#        [0.15952906],
#        [0.07146868],
#        [0.06568906],
#        [0.07322877],
#        [0.02809538],
#        [0.02994571],
#        [0.        ],
#        [0.03163037],
#        [0.03258334],
#        [0.03487093],
#        [0.01996711],
#        [0.0426008 ],
#        [0.04560352],
#        [0.05117893],
#        [0.04139415],
#        [0.03538341],
#        [0.03400096]])

# %%
#Create training data set
#This is where we shift the data

train_data=scaled_data[0:training_data_len,:]

#split the data into x_train and y_train data sets

x_train =[]
y_train=[]

for i in range(60,len(train_data)):
  x_train.append(train_data[i-60:i,0])
  y_train.append(train_data[i,0])

# %%
len(x_train)
# Out:
# 233

# %%
len(y_train)
# Out:
# 233

# %%
#convert train data to numpy arrays
x_train,y_train=np.array(x_train),np.array(y_train)

#Reshape
x_train.shape
# Out:
# (233, 60)

# %%
x_train=np.reshape(x_train,(x_train.shape[0],x_train.shape[1],1))
x_train.shape
# Out:
# (233, 60, 1)

# %%
# build LSTM model
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(x_train.shape[1],1)))
model.add(LSTM(50,return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

# %%
#compile the model
model.compile(optimizer='adam',loss='mean_squared_error')

# %%
#train the model
model.fit(x_train,y_train,batch_size=1,epochs=1)
# Out:
# 233/233 [==============================] - 8s 23ms/step - loss: 0.0188

# %%
#create the testing data set
#create a new array containing scaled values from index 1543 to 2003
test_data=scaled_data[training_data_len - 60:,:]
#create the data sets x_test and y_test
x_test=[]
y_test=dataset[training_data_len:,:]
for i in range(60,len(test_data)):
  x_test.append(test_data[i-60:i,0])

#convert the data to a numpy array
x_test=np.array(x_test)
#reshape
x_test=np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))

# %%
predictions=model.predict(x_test)
predictions=scaler.inverse_transform(predictions)

# %%
train=data[:training_data_len]
valid=data[training_data_len:]
valid['Predictions']=predictions

#visualize the data
plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Date',fontsize=18)
plt.ylabel('Close Price USD($)',fontsize=18)
plt.plot(train['Close'])
plt.plot(valid[['Close','Predictions']])
plt.legend(['Train','Val','Predictions'],loc='lower right')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# **Time Series Final Project Brainstorm - exercise**

# %% [markdown]
# *   Climate Change Forecast
#
# *   Food Demand Forecasting
# *   List item
#
#
# *   Using XGBoost and its variants to predict Stock Prices and hook it up to https://alpaca.markets/
#
#
# *   Data Science Tournament, you can get paid to build financial models! https://numer.ai/
#
#
#
#
#
# *   Want to go more in depth into Making money with the power of data science?  I highly recommend this textbook! https://www.amazon.ca/Advances-Financial-Machine-Learning-Marcos/dp/1119482089/ref=asc_df_1119482089/?tag=googleshopc0c-20&linkCode=df0&hvadid=292982483438&hvpos=&hvnetw=g&hvrand=3604397138690398481&hvpone=&hvptwo=&hvqmt=&hvdev=c&hvdvcmdl=&hvlocint=&hvlocphy=9001010&hvtargid=pla-422557754574&psc=1
